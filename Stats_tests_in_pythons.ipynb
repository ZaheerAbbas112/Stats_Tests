# %% [markdown]
# # 1. Shapiro Wilk Test
# Test  whether a data sample has a Gaussian distribution(Normaly distributed)
#
# # Assumptions
# 1. observations in each sample are independent and distributed (iid)
# 2. interpretation
#
# - H0 (null hypothesis): the sample has a Gaussian Normal distribution
# - H1 (alternate hypothesis): the sample does not have a Gaussian/Normal distribution

# %%
pip install scipy

# %%
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
data = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
shapiro(data)
# Out:
# ShapiroResult(statistic=0.8934680223464966, pvalue=0.21651922166347504)

# %%
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
data = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data) # no result for stat,p

# %%
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
data = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print("stat=" ,stat) # now it will show the results fir stat, and P
print("p=", p)
print('stat=%.3f, p=%.3f' % (stat,p))
# Out:
# stat= 0.8934680223464966
# p= 0.21651922166347504
# stat=0.893, p=0.217

# %%
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
data = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print("stat=" ,stat) # now it will show the results fir stat, and P
print("p=", p)
if p>0.05:
    print('The data is normal')
else:
    print('The data is not normal')
# Out:
# stat= 0.8934680223464966
# p= 0.21651922166347504
# The data is normal

# %%
# Example of the Shapiro-Wilk Normality Test
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
data = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p = shapiro(data)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('Probably Gaussian')
else:
    print('Probably not Gaussian')
# Out:
# stat=0.893, p=0.217
# Probably Gaussian

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
ks = sns.load_dataset('titanic')
ks['age'].hist()  # make the histogram
# Out:
# <AxesSubplot: >

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
ks = sns.load_dataset('titanic')
sns.boxplot(ks['age'])  # make the box plot
# Out:
# <AxesSubplot: >

# %%
from scipy.stats import shapiro 
stat, p = shapiro(ks['age'])
print("stat=" ,stat) 
print("p=", p)
# Out:
# stat= nan
# p= 1.0

# %%
from scipy.stats import shapiro # All works of stats will be on Scipy library, For Shapiro test we will install Shapiro
stat, p = shapiro(ks['age'])
print("stat=" ,stat) # now it will show the results fir stat, and P
print("p=", p)
if p>0.05:
    print('The data is normal')
else:
    print('The data is not normal')
# Out:
# stat= nan
# p= 1.0
# The data is normal

# %%
# Normality test
from scipy.stats import shapiro 
ks = ks.dropna()  # drop na
# sns.boxplot(ks['age'])
stat, p=shapiro(ks['age'])
if p>0.05:
    print('The data is normal')
else:
    print('The data is not normal')
# Out:
# The data is normal

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
ks = sns.load_dataset('titanic')
sns.boxplot(ks['fare'])
# Out:
# <AxesSubplot: >

# %%
from scipy.stats import shapiro 
stat, p = shapiro(ks['fare'])
sns.boxplot(ks['fare'])
print("stat=" ,stat) 
print("p=", p)
if p>0.05:
    print('The data is normal')
else:
    print('The data is not normal')
# Out:
# stat= 0.5218917727470398
# p= 1.0789998175301091e-43
# The data is not normal

# %%
ks['fare'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # 2- Correlation test
#
# # 1- Pearson's Correlation Coefficient
#
# Test whether two samples have a linear relationship
# # Assumptions
# 1. observations in each sample are independent and identically distributed (iid)
# 2. obdervstions in each sample are normally distributed
# 3. observations in each sample have the same variance
# 4. interpretation
#
# - H0: the two samples are independent.\
# - H1: there is a dependency between the samples

# %%
# example of the Pearson's Correlation test
from scipy.stats import pearsonr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p= pearsonr(data1,data2)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably independent')
else: 
    print('probably dependent')
# Out:
# stat=0.688, p=0.028
# probably dependent

# %% [markdown]
# # 2- Spearman's Rank Correlation
# Test whether two sample have a monotonic relationship
#
# # Assumptions
# 1. observations in each sample are independent and identically distributed (iid)
# 2. obdervstions in each sample can be ranked
# 3. interpretation
#
# - H0: the two samples are independent.
# - H1: there is a dependency between the samples

# %%
# example of the Spearman's Rank Correlation Test
from scipy.stats import spearmanr
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p= spearmanr(data1,data2)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably independent')
else: 
    print('probably dependent')
# Out:
# stat=0.855, p=0.002
# probably dependent

# %% [markdown]
# # 3- Chi-Squared Test
#
# Test whether two categorical variables are related or independent
#
# # Assumptions
#
# 1. observatios used in the calculation of the contingency table are independent. 25 or more examples in each cell of the contingency table.
# 2. interpretation
#
# - H0: the two samples are independent
# - H1: there is a dependency between the samples

# %%
# example of the Chi-Squared Test
from scipy.stats import chi2_contingency
table = [[10,20,30], [6,9,17]]
stat, p, dof, expected = chi2_contingency(table)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably independent')
else:
    print('probably dependent')
# Out:
# stat=0.272, p=0.873
# probably independent

# %% [markdown]
# # 3- Parametric Statistical Hypothesis Test
#
# # 1- Student's t-test
# Tests whether the means of two inpendent samples are significantly different
#
# # Assumptions
# 1. observations in each  sample are independent and identically  distributed(iid)
# 2. observations in each sample are normally distributed
# 3. observations in each sample have the same variance
# 4. interpretation
#
# - H0: the means o the samples are equal
# - H1: the means of the samples are unequal

# %%
# example of the Student's t-tst
from scipy.stats import ttest_ind
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p= ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably the same distribution')
else:
    print('probably different distribution')
# Out:
# stat=0.515, p=0.613
# probably the same distribution

# %% [markdown]
# # 2- Paired Student's t-test
#
# Tests whether the means of two paired samples are significantly different
#
# - H0: the means of the samples are equal
# - H1: the means of the samples are not equal

# %%
# example
from scipy.stats import ttest_rel
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
stat, p= ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably the same distribution')
else:
    print('probably different distribution')
# Out:
# stat=0.515, p=0.613
# probably the same distribution

# %%
# example
from scipy.stats import ttest_rel
# data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
# data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
data1 = ks['age']
data2 = ks['fare']
stat, p= ttest_ind(data1,data2)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably the same distribution')
else:
    print('probably different distribution')
# Out:
# stat=nan, p=nan
# probably different distribution

# %% [markdown]
# # 4- Analysis of Variance Test (ANOVA)
# Tests whether the means of two or more independent samples are significantly different
#
# # Assumptions
# 1. observations in each sample are independent and identically distributed(iid)
# 2. observations in each sample are normally distributed
# 3. observations in each sample have the same variance
# 4. interpretation
#
# - H0: the means of the samples are equal
# - H1: one or more of the means of the samples are unequal

# %%
from scipy.stats import f_oneway
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [0.353, 3.517, 0.125, -7.545, -0.555, -1.536, 3.350, -1.578, -3.537, -1.579]
data3 = [0.873, 2.817, 0.121, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
stat, p= f_oneway(data1,data2,data3)
print('stat=%.3f, p=%.3f' % (stat,p))
if p>0.05:
    print('probably the same distribution')
else:
    print('probably different distribution')
# Out:
# stat=0.242, p=0.787
# probably the same distribution
